# %%
# !wget "https://huggingface.co/datasets/rhasspy/piper-checkpoints/resolve/main/ru/ru_RU/ruslan/medium/epoch=2436-step=1724372.ckpt"
# Out:
# --2025-12-10 14:41:03--  https://huggingface.co/datasets/rhasspy/piper-checkpoints/resolve/main/ru/ru_RU/ruslan/medium/epoch=2436-step=1724372.ckpt
# Resolving huggingface.co (huggingface.co)... 18.165.122.120, 18.165.122.101, 18.165.122.30, ...
# Connecting to huggingface.co (huggingface.co)|18.165.122.120|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python3 -m piper.train fit \
  --data.voice_name "nata" \
  --data.csv_path ./nataha/train.csv \
  --data.audio_dir ./nataha/train \
  --model.sample_rate 22050 \
  --data.espeak_voice "ru" \
  --data.cache_dir  ./nata_cache/ \
  --data.config_path ./nata_config.json \
  --data.batch_size 16 \
  --ckpt_path "./epoch=2436-step=1724372.ckpt"
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /opt/venv/lib/python3.12/site-packages/lightning/fabric/utilities/seed.py:42: No seed found, seed set to 0
# Seed set to 0
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO:piper.train.vits.dataset:Processing utterances...
